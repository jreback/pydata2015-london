# %% [markdown]
# dask example
# http://matthewrocklin.com/blog/tags.html#dask-ref

# %%
import dask.dataframe as dd
from dask import threaded, multiprocessing

# %%
pd.__version__
# Out:
# '0.16.1-85-g4e2acd1'

# %%
N = int(1e8)
df = DataFrame({'key' : np.random.randint(0,1000,size=N), 'value' : np.random.randn(N)})
recarray = df.to_records()
ddf = dd.from_array(recarray, chunksize=25000000)

# %%
# %timeit df.groupby('key').value.mean()
# Out:
# 1 loops, best of 3: 4.59 s per loop

# %%
# %timeit ddf.groupby('key').value.mean().compute()
# Out:
# 1 loops, best of 3: 6.49 s per loop

# %%
# %timeit ddf.groupby('key').value.mean().compute(get=threaded.get)
# Out:
# 1 loops, best of 3: 3.77 s per loop

# %%
# %timeit -n 1 ddf.groupby('key').value.mean().compute(get=multiprocessing.get)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-56-e7c9cb21f163> in <module>()
# ----> 1 get_ipython().magic(u"timeit -n 1 ddf.groupby('key').value.mean().compute(get=multiprocessing.get)")
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2305         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2306         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2307         return self.run_line_magic(magic_name, magic_arg_s)
#    2308
#    2309     #-------------------------------------------------------------------------
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2226                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2227             with self.builtin_trap:
# -> 2228                 result = fn(*args,**kwargs)
#    2229             return result
#    2230
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, line, cell)
#    1039                     break
#    1040                 number *= 10
# -> 1041         all_runs = timer.repeat(repeat, number)
#    1042         best = min(all_runs) / number
#    1043         if not quiet :
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/timeit.pyc in repeat(self, repeat, number)
#     227         r = []
#     228         for i in range(repeat):
# --> 229             t = self.timeit(number)
#     230             r.append(t)
#     231         return r
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in timeit(self, number)
#     130         gc.disable()
#     131         try:
# --> 132             timing = self.inner(it, self.timer)
#     133         finally:
#     134             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/dataframe/core.pyc in compute(self, **kwargs)
#      92
#      93     def compute(self, **kwargs):
# ---> 94         return compute(self, **kwargs)[0]
#      95
#      96     def _keys(self):
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/dataframe/core.pyc in compute(*args, **kwargs)
#      56     dsk = merge(*[arg.dask for arg in args])
#      57     keys = [arg._keys() for arg in args]
# ---> 58     results = get(dsk, keys, **kwargs)
#      59
#      60     return list(map(_concat, results))
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/dataframe/core.pyc in get(dsk, keys, get, **kwargs)
#     803     from .optimize import optimize
#     804     dsk2 = optimize(dsk, keys, **kwargs)
# --> 805     return get(dsk2, keys, **kwargs)  # use synchronous scheduler for now
#     806
#     807
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/multiprocessing.pyc in get(dsk, keys, optimizations, num_workers, func_loads, func_dumps)
#      49         # Run
#      50         result = get_async(apply_async, len(pool._pool), dsk2, keys,
# ---> 51                            queue=queue)
#      52     finally:
#      53         if cleanup:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/async.pyc in get_async(apply_async, num_workers, dsk, result, cache, debug_counts, queue, raise_on_exception, **kwargs)
#     438     # Seed initial tasks into the thread pool
#     439     while state['ready'] and len(state['running']) < num_workers:
# --> 440         fire_task()
#     441
#     442     # Main loop, wait on tasks to finish, insert new ones
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/async.pyc in fire_task()
#     434         # Submit
#     435         apply_async(execute_task, args=[key, dsk[key], data, queue,
# --> 436                                         raise_on_exception])
#     437
#     438     # Seed initial tasks into the thread pool
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/toolz-0.7.1-py2.7.egg/toolz/functoolz.pyc in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         try:
# --> 216             return self._partial(*args, **kwargs)
#     217         except TypeError:
#     218             # If there was a genuine TypeError
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dask/multiprocessing.pyc in dill_apply_async(apply_async, func, args, kwds, func_loads, func_dumps)
#      68     dumps = func_dumps or _globals.get('func_dumps') or dill.dumps
#      69     sfunc = dumps(func)
# ---> 70     sargs = dumps(args)
#      71     skwds = dumps(kwds)
#      72     return apply_async(curry(apply_func, loads=func_loads),
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in dumps(obj, protocol, byref, fmode)
#     190     """pickle an object to a string"""
#     191     file = StringIO()
# --> 192     dump(obj, file, protocol, byref, fmode)#, strictio)
#     193     return file.getvalue()
#     194
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in dump(obj, file, protocol, byref, fmode)
#     180             return
#     181     # end hack
# --> 182     pik.dump(obj)
#     183     # return to saved settings
#     184     pik._byref = _byref
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in dump(self, obj)
#     222         if self.proto >= 2:
#     223             self.write(PROTO + chr(self.proto))
# --> 224         self.save(obj)
#     225         self.write(STOP)
#     226
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_list(self, obj)
#     598
#     599         self.memoize(obj)
# --> 600         self._batch_appends(iter(obj))
#     601
#     602     dispatch[ListType] = save_list
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in _batch_appends(self, items)
#     631                 write(MARK)
#     632                 for x in tmp:
# --> 633                     save(x)
#     634                 write(APPENDS)
#     635             elif n:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     546         if n <= 3 and proto >= 2:
#     547             for element in obj:
# --> 548                 save(element)
#     549             # Subtle.  Same as in the big comment below.
#     550             if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in save_function(pickler, obj)
#     624                                 obj.func_globals, obj.func_name,
#     625                                 obj.func_defaults, obj.func_closure,
# --> 626                                 obj.__dict__), obj=obj)
#     627     else:
#     628         log.info("F2: %s" % obj)
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     399         else:
#     400             save(func)
# --> 401             save(args)
#     402             write(REDUCE)
#     403
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     560         write(MARK)
#     561         for element in obj:
# --> 562             save(element)
#     563
#     564         if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     546         if n <= 3 and proto >= 2:
#     547             for element in obj:
# --> 548                 save(element)
#     549             # Subtle.  Same as in the big comment below.
#     550             if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in save_cell(pickler, obj)
#     824     def save_cell(pickler, obj):
#     825         log.info("Ce: %s" % obj)
# --> 826         pickler.save_reduce(_create_cell, (obj.cell_contents,), obj=obj)
#     827         return
#     828
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     399         else:
#     400             save(func)
# --> 401             save(args)
#     402             write(REDUCE)
#     403
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     546         if n <= 3 and proto >= 2:
#     547             for element in obj:
# --> 548                 save(element)
#     549             # Subtle.  Same as in the big comment below.
#     550             if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     417
#     418         if state is not None:
# --> 419             save(state)
#     420             write(BUILD)
#     421
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in save_module_dict(pickler, obj)
#     656             # we only care about session the first pass thru
#     657             pickler._session = False
# --> 658         StockPickler.save_dict(pickler, obj)
#     659     return
#     660
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     647
#     648         self.memoize(obj)
# --> 649         self._batch_setitems(obj.iteritems())
#     650
#     651     dispatch[DictionaryType] = save_dict
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     679                 for k, v in tmp:
#     680                     save(k)
# --> 681                     save(v)
#     682                 write(SETITEMS)
#     683             elif n:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     417
#     418         if state is not None:
# --> 419             save(state)
#     420             write(BUILD)
#     421
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in save_module_dict(pickler, obj)
#     656             # we only care about session the first pass thru
#     657             pickler._session = False
# --> 658         StockPickler.save_dict(pickler, obj)
#     659     return
#     660
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     647
#     648         self.memoize(obj)
# --> 649         self._batch_setitems(obj.iteritems())
#     650
#     651     dispatch[DictionaryType] = save_dict
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     679                 for k, v in tmp:
#     680                     save(k)
# --> 681                     save(v)
#     682                 write(SETITEMS)
#     683             elif n:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/site-packages/dill/dill.pyc in save_module_dict(pickler, obj)
#     656             # we only care about session the first pass thru
#     657             pickler._session = False
# --> 658         StockPickler.save_dict(pickler, obj)
#     659     return
#     660
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_dict(self, obj)
#     647
#     648         self.memoize(obj)
# --> 649         self._batch_setitems(obj.iteritems())
#     650
#     651     dispatch[DictionaryType] = save_dict
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in _batch_setitems(self, items)
#     679                 for k, v in tmp:
#     680                     save(k)
# --> 681                     save(v)
#     682                 write(SETITEMS)
#     683             elif n:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     546         if n <= 3 and proto >= 2:
#     547             for element in obj:
# --> 548                 save(element)
#     549             # Subtle.  Same as in the big comment below.
#     550             if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     546         if n <= 3 and proto >= 2:
#     547             for element in obj:
# --> 548                 save(element)
#     549             # Subtle.  Same as in the big comment below.
#     550             if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     329
#     330         # Save the reduce() output and finally memoize the object
# --> 331         self.save_reduce(obj=obj, *rv)
#     332
#     333     def persistent_id(self, obj):
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     417
#     418         if state is not None:
# --> 419             save(state)
#     420             write(BUILD)
#     421
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_tuple(self, obj)
#     560         write(MARK)
#     561         for element in obj:
# --> 562             save(element)
#     563
#     564         if id(obj) in memo:
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save(self, obj)
#     284         f = self.dispatch.get(t)
#     285         if f:
# --> 286             f(self, obj) # Call unbound method with explicit self
#     287             return
#     288
#
# /Users/jreback/anaconda/envs/pandas_gil/lib/python2.7/pickle.pyc in save_string(self, obj, pack)
#     484                 self.write(SHORT_BINSTRING + chr(n) + obj)
#     485             else:
# --> 486                 self.write(BINSTRING + pack("<i", n) + obj)
#     487         else:
#     488             self.write(STRING + repr(obj) + '\n')
#
# error: 'i' format requires -2147483648 <= number <= 2147483647
